# %%
import requests
from requests.exceptions import RequestException
from bs4 import BeautifulSoup
import csv
import time


def get_one_page(url):  # 获取网页
    print('正在加载' + url)
    headers = {'User-Agent': 'User-Agent:Mozilla/5.0'}
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.content
        return None
    except RequestException:
        return None


def parse_one_page(html):  # 对网页内容进行解析
    soup = BeautifulSoup(html, "lxml")
    info = soup.find('div', class_='wdetail')
    rows = []
    tr_list = info.find_all('tr')[1:]  # 使用从第二个tr开始取
    for index, tr in enumerate(tr_list):  # enumerate可以返回元素的位置及内容
        td_list = tr.find_all('td')
        date = td_list[0].text.strip().replace("\n", "")  # 取每个标签的text信息，并使用replace()函数将换行符删除
        weather = td_list[1].text.strip().replace("\n", "").split("/")[0].strip()
        temperature_high = td_list[2].text.strip().replace("\n", "").split("/")[0].strip()
        temperature_low = td_list[2].text.strip().replace("\n", "").split("/")[1].strip()
        rows.append((date, weather, temperature_high, temperature_low))
    return rows


cities = ['dalian']  #选取的城市，可更改
years = ['2016', '2017', '2018']  #选取年份，可更改
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']  #选取月份，可更改

if __name__ == '__main__':
    # os.chdir()  # 设置工作路径
    for city in cities:
        with open(city + '_weather.csv', 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['date','weather','temperature_high','temperature_low'])
            for year in years:
                for month in months:
                    url = 'http://www.tianqihoubao.com/lishi/' + city + '/month/' + year + month + '.html'
                    html = get_one_page(url)
                    content = parse_one_page(html)
                    writer.writerows(content)
                    print(city + year + month + ' is OK!')
                    time.sleep(3)
# Out:
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201601.html
# dalian201601 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201602.html
# dalian201602 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201603.html
# dalian201603 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201604.html
# dalian201604 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201605.html
# dalian201605 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201606.html
# dalian201606 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201607.html
# dalian201607 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201608.html
# dalian201608 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201609.html
# dalian201609 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201610.html
# dalian201610 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201611.html
# dalian201611 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201612.html
# dalian201612 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201701.html
# dalian201701 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201702.html
# dalian201702 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201703.html
# dalian201703 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201704.html
# dalian201704 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201705.html
# dalian201705 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201706.html
# dalian201706 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201707.html
# dalian201707 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201708.html
# dalian201708 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201709.html
# dalian201709 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201710.html
# dalian201710 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201711.html
# dalian201711 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201712.html
# dalian201712 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201801.html
# dalian201801 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201802.html
# dalian201802 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201803.html
# dalian201803 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201804.html
# dalian201804 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201805.html
# dalian201805 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201806.html
# dalian201806 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201807.html
# dalian201807 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201808.html
# dalian201808 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201809.html
# dalian201809 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201810.html
# dalian201810 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201811.html
# dalian201811 is OK!
# 正在加载http://www.tianqihoubao.com/lishi/dalian/month/201812.html
# dalian201812 is OK!
